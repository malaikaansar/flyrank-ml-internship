# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/malaikaansar/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 98 (delta 20), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 1.83 MiB | 8.70 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the page prioritization lane because FlyRank manages thousands of webpages, and it is important to identify which pages should be optimized first. This research explores whether search performance data can help rank pages according to their priority for optimization and support better decision-making.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This project improves the decision of which webpage should be optimized first. The output will help SEO specialists and content editors prioritize their work. A wrong recommendation may cause important pages to continue losing search traffic while less important pages receive attention first, leading to inefficient use of time and resources.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)

df.head()

df.describe()
# Out:
# Dataset Shape: (30000, 44)
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# ...

# %% [markdown]
# The dataset contains 30,000 pages and 44 features. The average search volume is approximately 158.88, the average impressions in the last 90 days are about 5,200.37, and the average word count is 3,107.76. These observations suggest that the dataset contains sufficient information to support page prioritization and further analysis.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support based on observed search performance data. The findings will be reported as observed, measured, and directional rather than causal. The project will not claim to predict Google's algorithm or guarantee future search rankings.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
